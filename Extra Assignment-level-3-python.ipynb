# %%
# print 'correct' if i == 10 
a=int(input("Value : "))
print("Value : ",a)
if a== 10:
    print("CORRECT")
# Out:
# Value :  10
# Value :  10
# CORRECT

# %%
# check the password, using if and else
a = input("Enter your password : ")
print("Your password is ",a)
if a == "HOPE@123":
    print("Your password is correct")
else:
    print("Your password is not correct")
# Out:
# Enter your password :  HOPE@123
# Your password is  HOPE@123
# Your password is correct

# %%
# Category the people by their age like children, adult, citizen, senior citizen
age = int(input("age : "))
print("age is ",age)
if age < 18:
    print("Children")
elif age >= 18 and age < 35:
    print("Adult")
elif age >= 35 and age < 60:
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# age :  20
# age is  20
# Adult

# %%
# Find whether given number is positive or negative
a = int(input("Enter any number : "))
print("The Number is ",a)
if a == 0:
    print("Numer is zero")
elif a < 0:
    print("Number is Negative")
else:
    print("Number is Positive")
# Out:
# Enter any number :  1
# The Number is  1
# Number is Positive

# %%
# check whether the given number is divisile by 5
a=int(input("Enter number to check : "))
print("The numer is ",a)
if a%5==0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter number to check :  22
# The numer is  22
# Number is not divisible by 5
