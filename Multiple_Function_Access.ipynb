# %%
from Multiple_Functions import Multiple_Functions

# %%
Multiple_Functions.BMI()
# Out:
# Enter the BMI Index:  27
# The BMI Index :  27.0
# Over Weight

# %%
Multiple_Functions.Add()
# Out:
# a =  23
# b =  64
# a :  23
# b :  64
# Add =  87

# %%
Multiple_Functions.Sub()
# Out:
# a =  54
# b =  24
# a :  54
# b :  24
# Sub =  30

# %%
Multiple_Functions.Mul()
# Out:
# a =  10
# b =  30
# a :  10
# b :  30
# Mul =  300

# %%
Multiple_Functions.Div()
# Out:
# a =  20
# b =  6
# a :  20
# b :  6
# Float Div =  3.3333333333333335

# %%
Multiple_Functions.Floor_Div()
# Out:
# a =  20
# b =  6
# a :  20
# b :  6
# Floor Div =  3

# %%
Multiple_Functions.Modulo()
# Out:
# a =  40
# b =  3
# a :  40
# b :  3
# Modulo =  1

# %%
Multiple_Functions.Power()
# Out:
# a =  2
# b =  4
# a :  2
# b :  4
# Power =  16

# %%
Multiple_Functions.Age_Category()
# Out:
# age :  21
# The age is  21
# Adult

# %%
Multiple_Functions.Num_Check()
# Out:
# Enter any number :  -353
# The Number is  -353
# Number is Negative

# %%
Multiple_Functions.Subfields()
# Out:
# Sub-fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
Multiple_Functions.OddEven()
# Out:
# Enter a number:  45636
# The Number is  45636
# 45636 is Even number

# %%
Multiple_Functions.Eligible_For_Marriage()
# Out:
# Your Gender :  Male
# Your Age :  20
# The Gender is  Male
# The Age is  20
# Not Eligile

# %%
Multiple_Functions.percentage()
# Out:
# Subject 1 :  98
# Subject 2 :  78
# Subject 3 :  83
# Subject 4 :  96
# Subject 5 :  81
# The subject 1 is  98
# The subject 1 is  78
# The subject 1 is  83
# The subject 1 is  96
# The subject 1 is  81
# Total :  436
# Percentage :  87.2

# %%
Multiple_Functions.Area_of_triange()
# Out:
# Height :  32
# Breadth :  34
# The Height is  32
# The Breadth is  34
# Area formula: (Height*Breadth)/2
# Area of Triangle :  544.0

# %%
Multiple_Functions.Perimeter_of_triangle()
# Out:
# Height1 :  4
# Height2 :  8
# Breadth1 :  8
# The Height1 is  4
# The Height2 is  8
# The Breadth1 is  8
# Perimeter formula: Height1+Height2+Breadth1
# Perimeter of Triangle :  20
