# %%
class SubfieldsInAI:
    def Subfields():
        print("Sub-fields in AI are :")
        print("Machine Learning")
        print("Neural Networks")
        print("Vision")
        print("Robotics")
        print("Speech Processing")
        print("Natural Language Processing")
        
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are :
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a function that checks whether the given number is Odd or Even
class OddEven:
    def OddEven(a):
        if a%2 == 0:
            print(a, "is Even number")
        else:
            print(a, "is Odd number")
            
a = int(input("Enter a number: "))
print("The number is ",a)
OddEven.OddEven(a)
# Out:
# Enter a number:  52452
# The number is  52452
# 52452 is Even number

# %%
#### Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female
class ElegiblityForMarriage:
    def Eligible(Gender, Age):
        if Gender == "Male":
            if Age >= 21:
                print("Elgible")
            else:
                print("Not Eligile")
        else:
            if Age >= 18:
                print("Elgible")
            else:
                print("Not Eligile")
                
Gender = input("Your Gender : ")
print("The Gender is ",Gender)
Age = int(input("Your Age : "))
print("The Age is ",Age)
ElegiblityForMarriage.Eligible(Gender, Age)
# Out:
# Your Gender :  Male
# The Gender is  Male
# Your Age :  20
# The Age is  20
# Not Eligile

# %%
# calculate the percentage of your 10th mark
class FindPercent:
    def percentage(Total):
        percentage = (Total * 100)/500
        print("Total : ",Total)
        print("Percentage : ",percentage)
S1=int(input("Subject 1 : "))
S2=int(input("Subject 2 : "))
S3=int(input("Subject 3 : "))
S4=int(input("Subject 4 : "))
S5=int(input("Subject 5 : "))

print("The subject 1 is ",S1)
print("The subject 1 is ",S2)
print("The subject 1 is ",S3)
print("The subject 1 is ",S4)
print("The subject 1 is ",S5)

Total = S1+S2+S3+S4+S5
FindPercent.percentage(Total)
# Out:
# Subject 1 :  98
# Subject 2 :  87
# Subject 3 :  95
# Subject 4 :  95
# Subject 5 :  83
# The subject 1 is  98
# The subject 1 is  87
# The subject 1 is  95
# The subject 1 is  95
# The subject 1 is  83
# Total :  458
# Percentage :  91.6

# %%
#print area and perimeter of triangle using class and functions
class triangle:
    def Area_of_triange(Height, Breadth):
        print("Area formula: (Height*Breadth)/2")
        Area = (Height*Breadth)/2
        print("Area of Triangle : ",Area)
    def Perimeter_of_triangle(Height1, Height2, Breadth1):
        print("Perimeter formula: Height1+Height2+Breadth1")
        Perimeter = Height1+Height2+Breadth1
        print("Perimeter of Triangle : ",Perimeter)
        
Height=int(input("Height : "))
Breadth=int(input("Breadth : "))
print("The Height is ",Height)
print("The Breadth is ",Breadth)
triangle.Area_of_triange(Height, Breadth)

Height1=int(input("Height1 : "))
Height2=int(input("Height2 : "))
Breadth1=int(input("Breadth1 : "))
print("The Height1 is ",Height1)
print("The Height2 is ",Height2)
print("The Breadth1 is ",Breadth1)
triangle.Perimeter_of_triangle(Height1, Height2, Breadth1)
# Out:
# Height :  32
# Breadth :  34
# The Height is  32
# The Breadth is  34
# Area formula: (Height*Breadth)/2
# Area of Triangle :  544.0
# Height1 :  2
# Height2 :  4
# Breadth1 :  4
# The Height1 is  2
# The Height2 is  4
# The Breadth1 is  4
# Perimeter formula: Height1+Height2+Breadth1
# Perimeter of Triangle :  10
