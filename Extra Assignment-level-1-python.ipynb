# %%
#print statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy input
a=input("Enter your institute name? : ")
print("The Institute Name : ",a)
# Out:
# Enter your institute name? :  HOPE AI
# The Institute Name :  HOPE AI

# %%
#Buy input
a=input("Enter your name : ")
b=input("Enter your age : ")
c=input("Enter your Institute name : ")
d=input("Enter your degree : ")
print("your name : ",a)
print("your age : ",b)
print("your School name : ",c)
print("your degree : ",d)
# Out:
# Enter your name :  Prabhu
# Enter your age :  20
# Enter your Institute name :  Sethu
# Enter your degree :  BE (CSE) [AIML]
# your name :  Prabhu
# your age :  20
# your School name :  Sethu
# your degree :  BE (CSE) [AIML]

# %%
#Addition
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Add = ",a+b)
# Out:
# a =  43
# b =  34
# a =  43
# b =  34
# Add =  77

# %%
#Subtraction
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Sub = ",a-b)
# Out:
# a =  43
# b =  34
# a =  43
# b =  34
# Sub =  9

# %%
#Multiplication
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Mul = ",a*b)
# Out:
# a =  63
# b =  97
# a =  63
# b =  97
# Mul =  6111

# %%
#Division
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Float Div = ",a/b)
# Out:
# a =  76
# b =  31
# a =  76
# b =  31
# Float Div =  2.4516129032258065

# %%
#Floor Division
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Floor Div = ",a//b)
# Out:
# a =  76
# b =  31
# a =  76
# b =  31
# Floor Div =  2

# %%
#Modulo
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Modulo = ",a%b)
# Out:
# a =  76
# b =  31
# a =  76
# b =  31
# Modulo =  14

# %%
#Power
a=int(input("a = "))
b=int(input("b = "))
print("a = ",a)
print("b = ",b)
print("Power = ",a**b)
# Out:
# a =  4
# b =  4
# a =  4
# b =  4
# Power =  256
